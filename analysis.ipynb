# %%
import pandas as pd

# %%
df = pd.read_csv("generation/LEETCODE_EASY_EVAL.csv")

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0                          model  temperature  \
# 0               0         249  openaichat/gpt-3.5-turbo-0613          0.1
# 1               1          99  openaichat/gpt-3.5-turbo-0301          0.1
# 2               2         699          openaichat/gpt-4-0613          0.1
# 3               3         549          openaichat/gpt-4-0314          0.1
# 4               4         690          openaichat/gpt-4-0613          0.1
# ..            ...         ...                            ...          ...
# 195           195         246  openaichat/gpt-3.5-turbo-0613          0.1
# 196           196         188  openaichat/gpt-3.5-turbo-0613          0.1
# 197           197         488          openaichat/gpt-4-0314          0.1
# 198           198          38  openaichat/gpt-3.5-turbo-0301          0.1
# 199           199         638          openaichat/gpt-4-0613          0.1
#
#      max_tokens  trail        dataset  \
# 0          2000      0  leetcode_easy
# ...

# %%
df[df["Directly Usable"] == True]["model"].value_counts()
# Out:
# model
# openaichat/gpt-4-0314            26
# openaichat/gpt-3.5-turbo-0301    11
# openaichat/gpt-4-0613             5
# openaichat/gpt-3.5-turbo-0613     1
# Name: count, dtype: int64

# %%
print(df["answer"][0].replace("```python\n", "").replace("\n```", ""))
# Out:
# class Solution(object):
#     def theMaximumAchievableX(self, num, t):
#         """
#         :type num: int
#         :type t: int
#         :rtype: int
#         """
#         # Initialize x as num
#         x = num
#
#         # Loop t times
#         for _ in range(t):
#             # Increase x by 1 and num by 1
#             x += 1
#             num += 1
#
#         # Return the maximum achievable number
#         return x

# %%
df_gpt_4_0613 = df[df["model"] == "openaichat/gpt-4-0613"]
df_gpt_4_0613[-df_gpt_4_0613["answer"].str.startswith("```python")]
# Out:
#      Unnamed: 0.1  Unnamed: 0                  model  temperature  max_tokens  \
# 25             25         688  openaichat/gpt-4-0613          0.1        2000
# 32             32         649  openaichat/gpt-4-0613          0.1        2000
# 69             69         697  openaichat/gpt-4-0613          0.1        2000
# 91             91         626  openaichat/gpt-4-0613          0.1        2000
# 118           118         647  openaichat/gpt-4-0613          0.1        2000
# 132           132         620  openaichat/gpt-4-0613          0.1        2000
# 154           154         723  openaichat/gpt-4-0613          0.1        2000
# 170           170         695  openaichat/gpt-4-0613          0.1        2000
# 189           189         680  openaichat/gpt-4-0613          0.1        2000
#
#      trail        dataset                                                 id  \
# 25       0  leetcode_easy                   2733-neither-minimum-nor-maximum
# ...

# %%
df_gpt_4_0613[(df_gpt_4_0613["answer"].str.startswith("```python")) & (df_gpt_4_0613["Code_Submit"].str.contains("Accepted"))]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, model, temperature, max_tokens, trail, dataset, id, query, ref_answer, answer, latency, cost, date, timestamp, Code_Submit, Directly Usable]
# Index: []

# %%
df[df["model"] == "openaichat/gpt-4-0613"]
# Out:
#      Unnamed: 0.1  Unnamed: 0                  model  temperature  max_tokens  \
# 2               2         699  openaichat/gpt-4-0613          0.1        2000
# 4               4         690  openaichat/gpt-4-0613          0.1        2000
# 10             10         683  openaichat/gpt-4-0613          0.1        2000
# 15             15         722  openaichat/gpt-4-0613          0.1        2000
# 16             16         712  openaichat/gpt-4-0613          0.1        2000
# 20             20         615  openaichat/gpt-4-0613          0.1        2000
# 25             25         688  openaichat/gpt-4-0613          0.1        2000
# 31             31         653  openaichat/gpt-4-0613          0.1        2000
# 32             32         649  openaichat/gpt-4-0613          0.1        2000
# 39             39         666  openaichat/gpt-4-0613          0.1        2000
# 41             41         656  openaichat/gpt-4-0613          0.1        2000
# ...

# %%
df["timestamp"]
# Out:
# 0      07/11/2023, 01:04:13
# 1      07/11/2023, 00:53:34
# 2      07/11/2023, 01:58:07
# 3      07/11/2023, 01:30:17
# 4      07/11/2023, 01:56:39
#                ...
# 195    07/11/2023, 01:04:02
# 196    07/11/2023, 00:59:35
# 197    07/11/2023, 01:23:30
# 198    07/11/2023, 00:49:37
# 199    07/11/2023, 01:43:45
# Name: timestamp, Length: 200, dtype: object
